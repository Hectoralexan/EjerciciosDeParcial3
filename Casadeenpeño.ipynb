-- %% [markdown]
-- # [CasaDeEmmpeño]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [CasaDeEmmpeño]    Script Date: 20/06/2022 20:21:08 ******/
CREATE DATABASE [CasaDeEmmpeño]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'CasaDeEmmpeño', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\CasaDeEmmpeño.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'CasaDeEmmpeño_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\CasaDeEmmpeño_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [CasaDeEmmpeño] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [CasaDeEmmpeño].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [CasaDeEmmpeño] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET ARITHABORT OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [CasaDeEmmpeño] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [CasaDeEmmpeño] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET  DISABLE_BROKER 
GO
ALTER DATABASE [CasaDeEmmpeño] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [CasaDeEmmpeño] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [CasaDeEmmpeño] SET  MULTI_USER 
GO
ALTER DATABASE [CasaDeEmmpeño] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [CasaDeEmmpeño] SET DB_CHAINING OFF 
GO
ALTER DATABASE [CasaDeEmmpeño] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [CasaDeEmmpeño] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [CasaDeEmmpeño] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [CasaDeEmmpeño] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [CasaDeEmmpeño] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Empeño]

-- %%
USE [CasaDeEmmpeño]
GO

-- %%
/****** Object:  Table [dbo].[Empeño]    Script Date: 20/06/2022 20:21:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Empeño](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](50) NOT NULL,
	[Estado] [nchar](10) NOT NULL,
	[credito] [int] NOT NULL,
 CONSTRAINT [PK_Empeño] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %%
SET IDENTITY_INSERT [dbo].[Empeño] ON 
INSERT [dbo].[Empeño] ([id], [Nombre], [Estado], [credito]) VALUES (2, N'joyas', N'9         ', 100)
INSERT [dbo].[Empeño] ([id], [Nombre], [Estado], [credito]) VALUES (3, N'television', N'8         ', 300)
INSERT [dbo].[Empeño] ([id], [Nombre], [Estado], [credito]) VALUES (5, N'computadora', N'10        ', 200)
INSERT [dbo].[Empeño] ([id], [Nombre], [Estado], [credito]) VALUES (6, N'consola', N'8         ', 300)
SET IDENTITY_INSERT [dbo].[Empeño] OFF
GO

-- %% [markdown]
-- # [CasaDeEmmpeño]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [CasaDeEmmpeño] SET  READ_WRITE 
GO
